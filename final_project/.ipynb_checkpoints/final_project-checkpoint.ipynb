# %%
import pandas as pd

# %%
data = pd.read_csv('fertility_Diagnosis.txt')
data
# Out:
#     season   age  childish diseases  accident or serious trauma  \
# 0    -0.33  0.69                  0                           1
# 1    -0.33  0.94                  1                           0
# 2    -0.33  0.50                  1                           0
# 3    -0.33  0.75                  0                           1
# 4    -0.33  0.67                  1                           1
# ..     ...   ...                ...                         ...
# 95   -1.00  0.67                  1                           0
# 96   -1.00  0.61                  1                           0
# 97   -1.00  0.67                  1                           1
# 98   -1.00  0.64                  1                           0
# 99   -1.00  0.69                  0                           1
#
#     surgical intervention  high fevers in the last year  \
# 0                       1                             0
# 1                       1                             0
# ...

# %%
data.columns
# Out:
# Index(['season', 'age', 'childish diseases', 'accident or serious trauma',
#        'surgical intervention', 'high fevers in the last year',
#        'frequency of alcohol consumption', 'smoking habit',
#        'number of hours spent sitting per day', 'output'],
#       dtype='object')

# %%
bad = pd.read_csv('fertility.csv')

# %%
bad['Season'].replace({"winter":2, "spring":1, "summer":-2, "fall":-1 }, inplace= True)
bad['Childish diseases'].replace({"yes":1, "no":0}, inplace= True)
bad['Accident or serious trauma'].replace({"yes":1, "no":0}, inplace= True)
bad['Smoking habit'].replace({"daily":2, "occasional":1,"never":0}, inplace= True)
bad['Frequency of alcohol consumption'].replace({"once a weel":1,"hardly ever or never":0}, inplace= True)
bad['Surgical intervention'].replace({"yes":1,"no":0}, inplace= True)
bad.head()
# Out:
#    Season  Age Childish diseases Accident or serious trauma  \
# 0       1   30                no                        yes
# 1       1   35               yes                         no
# 2       1   27               yes                         no
# 3       1   32                no                        yes
# 4       1   30               yes                        yes
#
#   Surgical intervention High fevers in the last year  \
# 0                   yes       more than 3 months ago
# 1                   yes       more than 3 months ago
# 2                    no       more than 3 months ago
# 3                   yes       more than 3 months ago
# 4                    no       more than 3 months ago
#
#   Frequency of alcohol consumption Smoking habit  \
# 0                      once a week    occasional
# 1                      once a week         daily
# 2             hardly ever or never         never
# 3             hardly ever or never         never
# ...
