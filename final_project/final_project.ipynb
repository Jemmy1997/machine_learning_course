# %% [markdown]
# # Preprocessing

# %%
import pandas as pd

# %%
data = pd.read_csv('fertility.csv')
data
# Out:
# 0      Normal
# 1     Altered
# 2      Normal
# 3      Normal
# 4     Altered
#        ...
# 95     Normal
# 96     Normal
# 97     Normal
# 98     Normal
# 99     Normal
# Name: Diagnosis, Length: 100, dtype: object

# %%
dataFrame = pd.read_csv('fertility.csv')
dataFrame["Frequency of alcohol consumption"].unique()
# Out:
# array(['once a week', 'hardly ever or never', 'several times a week',
#        'several times a day', 'every day'], dtype=object)

# %%
dataFrame['Season'].replace({"winter":2, "spring":1, "summer":-2, "fall":-1 }, inplace= True)
dataFrame['Childish diseases'].replace({"yes":1, "no":0}, inplace= True)
dataFrame['Accident or serious trauma'].replace({"yes":1, "no":0}, inplace= True)
dataFrame['Smoking habit'].replace({"daily":2, "occasional":1,"never":0}, inplace= True)
dataFrame['Frequency of alcohol consumption'].replace({"once a week":4,"hardly ever or never":3,"several times a week":2,"several times a day":1, "every day":0 }, inplace= True)
dataFrame['Surgical intervention'].replace({"yes":1,"no":0}, inplace= True)
dataFrame['Diagnosis'].replace({"Normal":1,"Altered":0}, inplace= True)
dataFrame['High fevers in the last year'].replace({"more than 3 months ago":2,"less than 3 months ago":1,"no":0}, inplace= True)
dataFrame
# Out:
#     Season  Age  Childish diseases  Accident or serious trauma  \
# 0        1   30                  0                           1
# 1        1   35                  1                           0
# 2        1   27                  1                           0
# 3        1   32                  0                           1
# 4        1   30                  1                           1
# ..     ...  ...                ...                         ...
# 95       2   30                  1                           0
# 96       2   29                  1                           0
# 97       2   30                  1                           1
# 98       2   30                  1                           0
# 99       2   30                  0                           1
#
#     Surgical intervention  High fevers in the last year  \
# 0                       1                             2
# 1                       1                             2
# ...

# %%
Features = dataFrame[dataFrame.columns[:-1]]
Features.corr()
# Out:
#                                          Season       Age  Childish diseases  \
# Season                                 1.000000 -0.082905           0.138585
# Age                                   -0.082905  1.000000           0.098824
# Childish diseases                      0.138585  0.098824           1.000000
# Accident or serious trauma             0.112919  0.235735           0.162936
# Surgical intervention                  0.038098  0.254032          -0.140972
# High fevers in the last year          -0.287026  0.010837          -0.115601
# Frequency of alcohol consumption       0.027078 -0.316401          -0.037655
# Smoking habit                          0.037523  0.076990           0.090535
# Number of hours spent sitting per day  0.040459 -0.046645           0.025247
#
#                                        Accident or serious trauma  \
# Season                                                   0.112919
# ...

# %%
dataFrame.hist(bins=50, figsize=(20, 15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fba554788d0>,
# ...
#       dtype=object)

# %%
Features = dataFrame[dataFrame.columns[:-1]]
Classes = dataFrame[dataFrame.columns[-1]]

# %% [markdown]
# # Prepare DataSet

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(Features, Classes, test_size=0.1, random_state=42)

# %% [markdown]
# # Bayes Technique

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
y_pred_nb = gnb.fit(X_train, y_train).predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_nb))
# Out:
# Accuracy: 0.9

# %% [markdown]
# # Decision Tree Technique

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import pydot


tree_clf = DecisionTreeClassifier(max_depth=None)
tree_clf.fit(X_train, y_train)

export_graphviz(
tree_clf,
out_file="imgs/fert.dot",
feature_names=dataFrame.columns[:-1],
class_names=data['Diagnosis'].unique().tolist(),
rounded=True,
filled=True
)



(graph,) = pydot.graph_from_dot_file('imgs/fert.dot')
graph.write_png('imgs/fert.png')

# %% [markdown]
# ![title](imgs/fert.png)

# %%
from sklearn import metrics
y_pred_tree = tree_clf.predict(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_tree))
# Out:
# Accuracy: 0.8

# %%
for i in dataFrame['Age']:
    i =0
    
dataFrame['Age'] = dataFrame*5/8
dataFrame['Age']
# Out:
# 0     0.625
# 1     0.625
# 2     0.625
# 3     0.625
# 4     0.625
#       ...
# 95    1.250
# 96    1.250
# 97    1.250
# 98    1.250
# 99    1.250
# Name: Age, Length: 100, dtype: float64
